# %% [markdown]
# # 商用程式設計
# Chap 0
# * holle word
# * a+b
# * requests

# %%
print('Holle word')
# Out:
# Holle word

# %%
a=50
b=1000
a+b
# Out:
# 1050

# %%
import requests
a=requests.get('http://www.facebook.com/')
print(a.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" id="facebook" class="no_js">
# ...
